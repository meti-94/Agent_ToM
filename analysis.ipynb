# %%
import os
from local_evaluate import check_answer

def list_json_files(directory):
    return [f for f in os.listdir(directory) if f.endswith('.json') and os.path.isfile(os.path.join(directory, f))]

# %%
check_answer('./output/gsm8k/gemma-2-2b/06_152730')
# Out:
# len(file_list): 100
# Any result Accuracy: 58.000%
# Accuracy: 30.000%

# %%
check_answer('./output/gsm8k/gemma-2-2b/06_154456')
# Out:
# len(file_list): 100
# Any result Accuracy: 58.000%
# Accuracy: 31.000%

# %%
check_answer('./output/gsm8k/gemma-2-2b/06_160320')
# Out:
# len(file_list): 100
# Any result Accuracy: 58.000%
# Accuracy: 30.000%

# %%
check_answer('./output/gsm8k/gemma-2-2b/06_161723')
# Out:
# len(file_list): 100
# Any result Accuracy: 58.000%
# Accuracy: 30.000%

# %%
check_answer('./output/gsm8k/gemma-2-2b/06_120234')
# Out:
# len(file_list): 50
# Any result Accuracy: 64.000%
# Accuracy: 40.000%

# %%
check_answer('output/svamp/gemma-2-2b/w_sae')
# Out:
# len(file_list): 300
# Any result Accuracy: 74.667%
# Accuracy: 53.000%

# %%
check_answer('output/svamp/gemma-2-2b/wo_sae')
# Out:
# len(file_list): 300
# Any result Accuracy: 75.333%
# Accuracy: 49.333%

# %%
check_answer('output/svamp/gemma-2-2b/s_r')
# Out:
# len(file_list): 300
# Any result Accuracy: 0.000%
# Accuracy: 49.333%

# %%
check_answer('output/gsm8k/gemma-2-2b/s_r')
# Out:
# len(file_list): 300
# Any result Accuracy: 0.000%
# Accuracy: 25.000%

# %%
check_answer('output/gsm8k/gemma-2-2b/wo_sae')
# Out:
# len(file_list): 300
# Any result Accuracy: 52.333%
# Accuracy: 34.000%

# %%
check_answer('output/gsm8k/gemma-2-2b/w_sae')
# Out:
# len(file_list): 300
# Any result Accuracy: 62.667%
# Accuracy: 37.667%

# %%
check_answer('output/gsm_hard/gemma-2-2b/w_sae')
# Out:
# len(file_list): 300
# Any result Accuracy: 26.000%
# Accuracy: 15.333%

# %%
check_answer('output/gsm_hard/gemma-2-2b/random_steer')
# Out:
# len(file_list): 300
# Any result Accuracy: 24.333%
# Accuracy: 14.333%

# %%
check_answer('output/gsm_hard/gemma-2-2b/wo_sae')
# Out:
# len(file_list): 300
# Any result Accuracy: 25.667%
# Accuracy: 12.333%

# %%
check_answer('output/gsm_hard/gemma-2-2b/s_r')
# Out:
# len(file_list): 300
# Any result Accuracy: 0.000%
# Accuracy: 9.000%

# %%
check_answer('output/gsm8k/gemma-2-2b/w_sae_intuitive')
# Out:
# len(file_list): 300
# Any result Accuracy: 62.000%
# Accuracy: 37.333%

# %%
check_answer('output/gsm8k/gemma-2-2b/29_040950')
# Out:
# len(file_list): 300
# Any result Accuracy: 62.333%
# Accuracy: 37.667%

# %%
check_answer('output/gsm8k/gemma-2-2b/29_065645')
# Out:
# len(file_list): 300
# Any result Accuracy: 61.667%
# Accuracy: 35.333%

# %%
check_answer('output/gsm8k/gemma-2-2b/05_094221/')
# Out:
# len(file_list): 1000
# Any result Accuracy: 60.400%
# Accuracy: 36.100%

# %%
check_answer('output/gsm8k/gemma-2-2b/05_094228/')
# Out:
# len(file_list): 1000
# Any result Accuracy: 60.400%
# Accuracy: 36.100%

# %%
check_answer('output/gsm8k/gemma-2-2b/05_094953/')
# Out:
# len(file_list): 1000
# Any result Accuracy: 61.600%
# Accuracy: 36.100%
