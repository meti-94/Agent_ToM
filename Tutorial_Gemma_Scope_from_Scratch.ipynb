# %% [markdown]
# # Gemma Scope Tutorial
#
# This is a barebones tutorial on how to use [Gemma Scope](https://huggingface.co/google/gemma-scope), Google DeepMind's suite of Sparse Autoencoders (SAEs) on every layer and sublayer of Gemma 2 2B and 9B. Sparse Autoencoders are an interpretability tool that act like a "microscope" on language model activations. They let us zoom in on dense, compressed activations, and expand them to a larger but sparser and seemingly more interpretable form, which can be a very useful tool when doing interpretability research!
#
# **Learn more:**
# * If you want to learn about Gemma Scope without writing any code, check out [this interactive demo](https://neuronpedia.org/gemma-scope) courtesy of [Neuronpedia](https://neuronpedia.org).
# * For an overview of Gemma Scope check out [the blog post](https://deepmind.google/discover/blog/gemma-scope-helping-the-safety-community-shed-light-on-the-inner-workings-of-language-models).
# * See [the technical report](https://storage.googleapis.com/gemma-scope/gemma-scope-report.pdf) for the technical details

# %% [markdown]
# For illustrative purposes, we begin with a lightweight tutorial that uses as few libraries as possible to outline how Gemma Scope works, and what Sparse Autoencoders are doing. This is deliberately a fairly minimalist tutorial, designed to make clear what is actually going on, but does not model research best practices.
#
# For any serious research with Gemma Scope, **we recommend using the [SAELens](https://jbloomaus.github.io/SAELens/) and [TransformerLens](https://transformerlensorg.github.io/TransformerLens/) libraries**, see [this tutorial](https://colab.research.google.com/github/jbloomAus/SAELens/blob/main/tutorials/tutorial_2_0.ipynb) on how to use [SAELens](https://jbloomaus.github.io/SAELens/) in practice.

# %% [markdown]
# ## Loading the Model

# %% [markdown]
# First, let's load the model:
#
# For simplicity we do this straight from [HuggingFace transformers](https://huggingface.co/docs/transformers/en/index), rather than using an interpretability focused library like [TransformerLens](https://transformerlensorg.github.io/TransformerLens/) or [nnsight](https://nnsight.net/)

# %%
import os
os.environ['HF_HOME'] = '/mnt/datadisk/Mehdi'
os.environ['CUDA_VISIBLE_DEVICES'] = '0,1'
from transformers import AutoModelForCausalLM, BitsAndBytesConfig, AutoTokenizer
from huggingface_hub import hf_hub_download, notebook_login
import numpy as np
import torch
# Out:
# /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %% [markdown]
# We load Gemma 2 2B, the smallest model that Gemma Scope works for. We load the base model, not the chat model, since that's where our SAEs are trained. Though the SAEs seem to transfer OK to these models. First, you'll need to authenticate with huggingface in order to download the model weights

# %%
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
torch.set_grad_enabled(False) # avoid blowing up mem

model = AutoModelForCausalLM.from_pretrained(
    "google/gemma-2-2b",
    device_map='auto',
)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
tokenizer =  AutoTokenizer.from_pretrained("google/gemma-2-2b")

# %% [markdown]
# Now we've loaded the model, let's try running it! We give it the prompt "Would you be able to travel through time using a wormhole?" and print the generated output

# %%
# The input text
prompt = "Would you be able to travel through time using a wormhole?"

# Use the tokenizer to convert it to tokens. Note that this implicitly adds a special "Beginning of Sequence" or <bos> token to the start
inputs = tokenizer.encode(prompt, return_tensors="pt", add_special_tokens=True).to("cuda")
print(inputs)

# Pass it in to the model and generate text
outputs = model.generate(input_ids=inputs, max_new_tokens=50)
print(tokenizer.decode(outputs[0]))
# Out:
# tensor([[     2,  18925,    692,    614,   3326,    577,   5056,   1593,   1069,
#            2177,    476,  47420,  18216, 235336]], device='cuda:0')
# <bos>Would you be able to travel through time using a wormhole?
#
# [Answer 1]
#
# Yes, you can travel through time using a wormhole.
#
# A wormhole is a theoretical object that connects two points in space-time. It is a tunnel through space-time that allows objects to travel from

# %% [markdown]
# ## Loading a Sparse Autoencoder

# %% [markdown]
# OK, so we have got Gemma 2 loaded and can sample from it to get sensible stuff. Now, let's load one of our SAEs.
#
# GemmaScope actually contains over four hundred SAEs, but for now we'll just load one on the residual stream at the end of layer 20 (of 26, note that layers start at 0 so this is the 21st layer. This is a fairly late layer, so the model should have time to find more abstract concepts!).
#
# See [the final section](https://colab.research.google.com/drive/17dQFYUYnuKnP6OwQPH9v_GSYUW5aj-Rp?authuser=2#scrollTo=E7zjkVseLSPp) for more information on how to load all the other SAEs in Gemma Scope
#
# <details><summary>What is the residual stream?</summary>
#
# Transformers have skip connections, which means that the output of each block is the output of each sublayer *plus* the input to the block. This means that each sublayer (attention or MLP) actually only has a fairly small effect on the output of the block, since most of it comes from all the earlier layers. We call the output of a block (including skip connections) the **residual stream**.
#
# Everything communicated from earlier layers to later layers must go via the residual stream, so it acts as a "bottleneck" in the transformer, essentially capturing everything the model has "thought" so far. This means it is often a natural thing to study, since it will contain everything important going on in the model.
# </details>

# %%
path_to_params = hf_hub_download(
    repo_id="google/gemma-scope-2b-pt-res",
    filename="layer_20/width_16k/average_l0_71/params.npz",
    force_download=False,
)

# %%
params = np.load(path_to_params)
pt_params = {k: torch.from_numpy(v).cuda() for k, v in params.items()}

# %%
{k:v.shape for k, v in pt_params.items()}
# Out:
# {'W_dec': torch.Size([16384, 2304]),
#  'W_enc': torch.Size([2304, 16384]),
#  'b_dec': torch.Size([2304]),
#  'b_enc': torch.Size([16384]),
#  'threshold': torch.Size([16384])}

# %%
pt_params["W_enc"].norm(dim=0)
# Out:
# tensor([1.2101, 1.1695, 0.9836,  ..., 1.0630, 0.9997, 1.1070], device='cuda:0')

# %% [markdown]
# ### Implementing the SAE

# %% [markdown]
# We now define the forward pass of the SAE for pedagogical purposes (in practice, we recommend using the implementation in SAELens)
#
# Gemma Scope is a collection of [JumpReLU SAEs](https://arxiv.org/abs/2407.14435), which is like a standard two layer (one hidden layer) neural network, but where the activation function is a **JumpReLU**: a ReLU with a discontinuous jump.

# %%
import torch.nn as nn
class JumpReLUSAE(nn.Module):
  def __init__(self, d_model, d_sae):
    # Note that we initialise these to zeros because we're loading in pre-trained weights.
    # If you want to train your own SAEs then we recommend using blah
    super().__init__()
    self.W_enc = nn.Parameter(torch.zeros(d_model, d_sae))
    self.W_dec = nn.Parameter(torch.zeros(d_sae, d_model))
    self.threshold = nn.Parameter(torch.zeros(d_sae))
    self.b_enc = nn.Parameter(torch.zeros(d_sae))
    self.b_dec = nn.Parameter(torch.zeros(d_model))

  def encode(self, input_acts):
    pre_acts = input_acts @ self.W_enc + self.b_enc
    mask = (pre_acts > self.threshold)
    acts = mask * torch.nn.functional.relu(pre_acts)
    return acts

  def decode(self, acts):
    return acts @ self.W_dec + self.b_dec

  def forward(self, acts):
    acts = self.encode(acts)
    recon = self.decode(acts)
    return recon

# %%
sae = JumpReLUSAE(params['W_enc'].shape[0], params['W_enc'].shape[1])
sae.load_state_dict(pt_params)
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### Running the SAE on model activatinos

# %% [markdown]
# Let's first get out some activations from the model at the SAE target site. We'll demonstrate how to do this 'manually' first, by using Pytorch hooks. Note that this is not particularly good practice, and it's probably more practical to use a library like TransformerLens to handle hooking the SAE into a model forward pass. But for illustrative purposes, it's useful to see how it's done.
#
# We can gather activations at a site by registering a hook. To keep this local, we can wrap this in a function that registers a hook, runs the model, saving the intermediate activation, then removes the hook. (This is basically what TransformerLens is doing under the hood)

# %%
def gather_residual_activations(model, target_layer, inputs):
  target_act = None
  def gather_target_act_hook(mod, inputs, outputs):
    nonlocal target_act # make sure we can modify the target_act from the outer scope
    target_act = outputs[0]
    return outputs
  handle = model.model.layers[target_layer].register_forward_hook(gather_target_act_hook)
  _ = model.forward(inputs)
  handle.remove()
  return target_act

# %%
target_act = gather_residual_activations(model, 20, inputs)

# %% [markdown]
# Now, we can run our SAE on the saved activations.

# %%
sae = sae.to('cuda:1')

# %%
sae_acts = sae.encode(target_act.to(torch.float32))
recon = sae.decode(sae_acts)

# %% [markdown]
# Let's just double check that the model looks sensible by checking that we explain a decent chunk of the variance:

# %%
1 - torch.mean((recon[:, 1:] - target_act[:, 1:].to(torch.float32)) **2) / (target_act[:, 1:].to(torch.float32).var())
# Out:
# tensor(0.8887, device='cuda:1')

# %% [markdown]
# This probably looks OK! This SAE is supposed to have an L0 of around 70, so let's just check that too:

# %%
(sae_acts > 1).sum(-1)
# Out:
# tensor([[7017,   47,   65,   70,   55,   72,   65,   75,   80,   72,   68,   93,
#            86,   89]], device='cuda:1')

# %% [markdown]
# It's always worth checking this sort of thing when you do this by hand to check that you haven't got the wrong site, or are missing a scaling factor or something like this. But here, our results all look like they are supposed to .
#
# Note that there's a bit of a gotcha here; our SAEs are *NOT* trained on the BOS token, because we found that this tended to be a large outlier and to mess up training. So they tend to give nonsense when we apply to them to it, and we need to be careful not to do this accidentally! We can see this above : the BOS token is a total outlier in terms of L0!

# %% [markdown]
# Let's look at the highest activating features on this input text, on each token position:

# %%
values, inds = sae_acts.max(-1)

inds
# Out:
# tensor([[ 6631,  5482, 10376,  1670, 11023,  7562,  9407,  8399, 12935, 10004,
#          10004, 10004, 12935,  3442]], device='cuda:1')

# %% [markdown]
# So we see that one of the max activating examples on this question is [SAE feature 10004](https://www.neuronpedia.org/gemma-2-2b/20-gemmascope-res-16k/10004), which fires on concepts related to time travel! We can visualise this below in the notebook, embedding the neuronpedia dashboard in the colab cell:

# %%
from IPython.display import IFrame
html_template = "https://neuronpedia.org/{}/{}/{}?embed=true&embedexplanation=true&embedplots=true&embedtest=true&height=300"

def get_dashboard_html(sae_release = "gemma-2-2b", sae_id="20-gemmascope-res-16k", feature_idx=0):
    return html_template.format(sae_release, sae_id, feature_idx)

html = get_dashboard_html(sae_release = "gemma-2-2b", sae_id="20-gemmascope-res-16k", feature_idx=10004)
IFrame(html, width=1200, height=600)
# Out:
#         <iframe
#             width="1200"
#             height="600"
#             src="https://neuronpedia.org/gemma-2-2b/20-gemmascope-res-16k/10004?embed=true&embedexplanation=true&embedplots=true&embedtest=true&height=300"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### SAELens
#
# We recommend using SAELens: https://github.com/jbloomAus/SAELens for research on SAEs. To load this SAE in SAELens, run the following:

# %%
# !pip install sae-lens

from sae_lens import SAE  # pip install sae-lens

sae, cfg_dict, sparsity = SAE.from_pretrained(
    release = "gemma-scope-2b-pt-res-canonical",
    sae_id = "layer_20/width_16k/canonical",
)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: sae-lens in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (6.12.1)
# Requirement already satisfied: babe<0.0.8,>=0.0.7 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from sae-lens) (0.0.7)
# Requirement already satisfied: datasets>=3.1.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from sae-lens) (4.0.0)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from sae-lens) (3.9.1)
# Requirement already satisfied: plotly>=5.19.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from sae-lens) (6.3.0)
# Requirement already satisfied: plotly-express>=0.4.1 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from sae-lens) (0.4.1)
# Requirement already satisfied: python-dotenv>=1.0.1 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from sae-lens) (1.1.1)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.1 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from sae-lens) (6.0.2)
# Requirement already satisfied: safetensors<1.0.0,>=0.4.2 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from sae-lens) (0.6.2)
# Requirement already satisfied: simple-parsing<0.2.0,>=0.1.6 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from sae-lens) (0.1.7)
# Requirement already satisfied: tenacity>=9.0.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from sae-lens) (9.1.2)
# Requirement already satisfied: transformer-lens<3.0.0,>=2.16.1 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from sae-lens) (2.16.1)
# Requirement already satisfied: transformers<5.0.0,>=4.38.1 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from sae-lens) (4.56.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.10.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from sae-lens) (4.15.0)
# Requirement already satisfied: pandas in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from babe<0.0.8,>=0.0.7->sae-lens) (2.3.2)
# Requirement already satisfied: py2store in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from babe<0.0.8,>=0.0.7->sae-lens) (0.1.21)
# Requirement already satisfied: graze in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from babe<0.0.8,>=0.0.7->sae-lens) (0.1.31)
# Requirement already satisfied: click in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->sae-lens) (8.2.1)
# Requirement already satisfied: joblib in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->sae-lens) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->sae-lens) (2025.9.1)
# Requirement already satisfied: tqdm in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->sae-lens) (4.67.1)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from simple-parsing<0.2.0,>=0.1.6->sae-lens) (0.17.0)
# Requirement already satisfied: accelerate>=0.23.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from transformer-lens<3.0.0,>=2.16.1->sae-lens) (1.10.1)
# Requirement already satisfied: beartype<0.15.0,>=0.14.1 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from transformer-lens<3.0.0,>=2.16.1->sae-lens) (0.14.1)
# Requirement already satisfied: better-abc<0.0.4,>=0.0.3 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from transformer-lens<3.0.0,>=2.16.1->sae-lens) (0.0.3)
# Requirement already satisfied: einops>=0.6.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from transformer-lens<3.0.0,>=2.16.1->sae-lens) (0.8.1)
# Requirement already satisfied: fancy-einsum>=0.0.3 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from transformer-lens<3.0.0,>=2.16.1->sae-lens) (0.0.3)
# Requirement already satisfied: jaxtyping>=0.2.11 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from transformer-lens<3.0.0,>=2.16.1->sae-lens) (0.3.2)
# Requirement already satisfied: numpy<2,>=1.24 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from transformer-lens<3.0.0,>=2.16.1->sae-lens) (1.26.4)
# Requirement already satisfied: rich>=12.6.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from transformer-lens<3.0.0,>=2.16.1->sae-lens) (14.1.0)
# Requirement already satisfied: sentencepiece in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from transformer-lens<3.0.0,>=2.16.1->sae-lens) (0.2.1)
# Collecting torch>=2.6 (from transformer-lens<3.0.0,>=2.16.1->sae-lens)
#   Using cached torch-2.8.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (30 kB)
# Requirement already satisfied: transformers-stream-generator<0.0.6,>=0.0.5 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from transformer-lens<3.0.0,>=2.16.1->sae-lens) (0.0.5)
# Requirement already satisfied: typeguard<5.0,>=4.2 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from transformer-lens<3.0.0,>=2.16.1->sae-lens) (4.4.4)
# Requirement already satisfied: wandb>=0.13.5 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from transformer-lens<3.0.0,>=2.16.1->sae-lens) (0.21.4)
# Requirement already satisfied: filelock in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from transformers<5.0.0,>=4.38.1->sae-lens) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from transformers<5.0.0,>=4.38.1->sae-lens) (0.34.4)
# Requirement already satisfied: packaging>=20.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from transformers<5.0.0,>=4.38.1->sae-lens) (25.0)
# Requirement already satisfied: requests in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from transformers<5.0.0,>=4.38.1->sae-lens) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from transformers<5.0.0,>=4.38.1->sae-lens) (0.22.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers<5.0.0,>=4.38.1->sae-lens) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers<5.0.0,>=4.38.1->sae-lens) (1.1.10)
# Requirement already satisfied: psutil in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from accelerate>=0.23.0->transformer-lens<3.0.0,>=2.16.1->sae-lens) (7.0.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from datasets>=3.1.0->sae-lens) (21.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from datasets>=3.1.0->sae-lens) (0.3.8)
# Requirement already satisfied: xxhash in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from datasets>=3.1.0->sae-lens) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from datasets>=3.1.0->sae-lens) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.1.0->sae-lens) (3.12.15)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.1.0->sae-lens) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.1.0->sae-lens) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.1.0->sae-lens) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.1.0->sae-lens) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.1.0->sae-lens) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.1.0->sae-lens) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.1.0->sae-lens) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.1.0->sae-lens) (1.20.1)
# Requirement already satisfied: idna>=2.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.1.0->sae-lens) (3.10)
# Requirement already satisfied: wadler-lindig>=0.1.3 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from jaxtyping>=0.2.11->transformer-lens<3.0.0,>=2.16.1->sae-lens) (0.1.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from pandas->babe<0.0.8,>=0.0.7->sae-lens) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from pandas->babe<0.0.8,>=0.0.7->sae-lens) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from pandas->babe<0.0.8,>=0.0.7->sae-lens) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from plotly>=5.19.0->sae-lens) (2.5.0)
# Requirement already satisfied: statsmodels>=0.9.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from plotly-express>=0.4.1->sae-lens) (0.14.5)
# Requirement already satisfied: scipy>=0.18 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from plotly-express>=0.4.1->sae-lens) (1.15.3)
# Requirement already satisfied: patsy>=0.5 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from plotly-express>=0.4.1->sae-lens) (1.0.1)
# Requirement already satisfied: six>=1.5 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->babe<0.0.8,>=0.0.7->sae-lens) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from requests->transformers<5.0.0,>=4.38.1->sae-lens) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from requests->transformers<5.0.0,>=4.38.1->sae-lens) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from requests->transformers<5.0.0,>=4.38.1->sae-lens) (2025.8.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from rich>=12.6.0->transformer-lens<3.0.0,>=2.16.1->sae-lens) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from rich>=12.6.0->transformer-lens<3.0.0,>=2.16.1->sae-lens) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=12.6.0->transformer-lens<3.0.0,>=2.16.1->sae-lens) (0.1.2)
# Collecting sympy>=1.13.3 (from torch>=2.6->transformer-lens<3.0.0,>=2.16.1->sae-lens)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from torch>=2.6->transformer-lens<3.0.0,>=2.16.1->sae-lens) (3.4.2)
# Requirement already satisfied: jinja2 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from torch>=2.6->transformer-lens<3.0.0,>=2.16.1->sae-lens) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93 (from torch>=2.6->transformer-lens<3.0.0,>=2.16.1->sae-lens)
#   Using cached nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime-cu12==12.8.90 (from torch>=2.6->transformer-lens<3.0.0,>=2.16.1->sae-lens)
#   Using cached nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti-cu12==12.8.90 (from torch>=2.6->transformer-lens<3.0.0,>=2.16.1->sae-lens)
#   Using cached nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch>=2.6->transformer-lens<3.0.0,>=2.16.1->sae-lens)
#   Using cached nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cublas-cu12==12.8.4.1 (from torch>=2.6->transformer-lens<3.0.0,>=2.16.1->sae-lens)
#   Using cached nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufft-cu12==11.3.3.83 (from torch>=2.6->transformer-lens<3.0.0,>=2.16.1->sae-lens)
#   Using cached nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-curand-cu12==10.3.9.90 (from torch>=2.6->transformer-lens<3.0.0,>=2.16.1->sae-lens)
#   Using cached nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch>=2.6->transformer-lens<3.0.0,>=2.16.1->sae-lens)
#   Using cached nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse-cu12==12.5.8.93 (from torch>=2.6->transformer-lens<3.0.0,>=2.16.1->sae-lens)
#   Using cached nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from torch>=2.6->transformer-lens<3.0.0,>=2.16.1->sae-lens) (0.7.1)
# Collecting nvidia-nccl-cu12==2.27.3 (from torch>=2.6->transformer-lens<3.0.0,>=2.16.1->sae-lens)
#   Using cached nvidia_nccl_cu12-2.27.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.8.90 (from torch>=2.6->transformer-lens<3.0.0,>=2.16.1->sae-lens)
#   Using cached nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.8.93 (from torch>=2.6->transformer-lens<3.0.0,>=2.16.1->sae-lens)
#   Using cached nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from torch>=2.6->transformer-lens<3.0.0,>=2.16.1->sae-lens) (1.13.1.3)
# Collecting triton==3.4.0 (from torch>=2.6->transformer-lens<3.0.0,>=2.16.1->sae-lens)
#   Using cached triton-3.4.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: setuptools>=40.8.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from triton==3.4.0->torch>=2.6->transformer-lens<3.0.0,>=2.16.1->sae-lens) (78.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=2.6->transformer-lens<3.0.0,>=2.16.1->sae-lens) (1.3.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.16.1->sae-lens) (3.1.45)
# Requirement already satisfied: platformdirs in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.16.1->sae-lens) (4.3.7)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.16.1->sae-lens) (6.32.1)
# Requirement already satisfied: pydantic<3 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.16.1->sae-lens) (2.11.9)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.16.1->sae-lens) (2.37.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from pydantic<3->wandb>=0.13.5->transformer-lens<3.0.0,>=2.16.1->sae-lens) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from pydantic<3->wandb>=0.13.5->transformer-lens<3.0.0,>=2.16.1->sae-lens) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from pydantic<3->wandb>=0.13.5->transformer-lens<3.0.0,>=2.16.1->sae-lens) (0.4.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer-lens<3.0.0,>=2.16.1->sae-lens) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer-lens<3.0.0,>=2.16.1->sae-lens) (5.0.2)
# Requirement already satisfied: dol in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from graze->babe<0.0.8,>=0.0.7->sae-lens) (0.3.20)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from jinja2->torch>=2.6->transformer-lens<3.0.0,>=2.16.1->sae-lens) (3.0.2)
# Requirement already satisfied: config2py in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from py2store->babe<0.0.8,>=0.0.7->sae-lens) (0.1.38)
# Requirement already satisfied: importlib_resources in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from py2store->babe<0.0.8,>=0.0.7->sae-lens) (6.5.2)
# Requirement already satisfied: i2 in /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages (from config2py->py2store->babe<0.0.8,>=0.0.7->sae-lens) (0.1.48)
# Using cached torch-2.8.0-cp310-cp310-manylinux_2_28_x86_64.whl (888.0 MB)
# Using cached nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
# Using cached nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
# Using cached nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
# Using cached nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
# Using cached nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
# Using cached nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
# Using cached nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
# Using cached nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
# Using cached nvidia_nccl_cu12-2.27.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.4 MB)
# Using cached nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
# Using cached nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Using cached triton-3.4.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.4 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Installing collected packages: triton, sympy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch
#   Attempting uninstall: triton
#     Found existing installation: triton 3.1.0
#     Uninstalling triton-3.1.0:
#       Successfully uninstalled triton-3.1.0
#   Attempting uninstall: sympy━━━━━━━━━━━━━━━━━━━  0/15 [triton]
#     Found existing installation: sympy 1.13.1  0/15 [triton]
#     Uninstalling sympy-1.13.1:━━━━━━━━━━━━━━  0/15 [triton]
#       Successfully uninstalled sympy-1.13.1━━━━━━━━━━━━━━━━━━━━━━━  1/15 [sympy]
#   Attempting uninstall: nvidia-nvtx-cu12━━━━━━━━━━━━━━━━━━━━━━━━━━  1/15 [sympy]
#     Found existing installation: nvidia-nvtx-cu12 12.4.127━━━━  1/15 [sympy]
#     Uninstalling nvidia-nvtx-cu12-12.4.127:━━━━━━━━━━━━━━━━━━━  1/15 [sympy]
#       Successfully uninstalled nvidia-nvtx-cu12-12.4.127━━━━━━  1/15 [sympy]
#   Attempting uninstall: nvidia-nvjitlink-cu12━━━━━━━━━━━━━━━━━  1/15 [sympy]
#     Found existing installation: nvidia-nvjitlink-cu12 12.4.127  1/15 [sympy]
#     Uninstalling nvidia-nvjitlink-cu12-12.4.127:━━━━━━━━━━━━━━  1/15 [sympy]
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.4.127━  1/15 [sympy]
#   Attempting uninstall: nvidia-nccl-cu12━━━━━━━━━━━━━━━━━━━━━━━━━━  3/15 [nvidia-nvjitlink-cu12]
#     Found existing installation: nvidia-nccl-cu12 2.21.5━━━━━━  3/15 [nvidia-nvjitlink-cu12]
#     Uninstalling nvidia-nccl-cu12-2.21.5:━━━━━━━━━━━━━━━━━━━━━  3/15 [nvidia-nvjitlink-cu12]
#       Successfully uninstalled nvidia-nccl-cu12-2.21.5━━━━━━━━  3/15 [nvidia-nvjitlink-cu12]
#   Attempting uninstall: nvidia-curand-cu12━━━━━━━━━━━━━━━━━━━━━━━━  4/15 [nvidia-nccl-cu12]]
#     Found existing installation: nvidia-curand-cu12 10.3.5.147  4/15 [nvidia-nccl-cu12]
#     Uninstalling nvidia-curand-cu12-10.3.5.147:━━━━━━━━━━━━━━━  4/15 [nvidia-nccl-cu12]
#       Successfully uninstalled nvidia-curand-cu12-10.3.5.147━━  4/15 [nvidia-nccl-cu12]
#   Attempting uninstall: nvidia-cuda-runtime-cu12━━━━━━━━━━━━━━━━━━  5/15 [nvidia-curand-cu12]
#     Found existing installation: nvidia-cuda-runtime-cu12 12.4.127  5/15 [nvidia-curand-cu12]
#     Uninstalling nvidia-cuda-runtime-cu12-12.4.127:━━━━━━━━━━━  5/15 [nvidia-curand-cu12]
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.4.1270m  5/15 [nvidia-curand-cu12]
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12━━━━━━━━━━━━━━━━  5/15 [nvidia-curand-cu12]
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.4.1270m  5/15 [nvidia-curand-cu12]
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.4.127:━━━━━━━━━━━━━━━━━  7/15 [nvidia-cuda-nvrtc-cu12]
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.4.127  7/15 [nvidia-cuda-nvrtc-cu12]
#   Attempting uninstall: nvidia-cuda-cupti-cu12━━━━━━━━━━━━━━━━━━━━  7/15 [nvidia-cuda-nvrtc-cu12]
#     Found existing installation: nvidia-cuda-cupti-cu12 12.4.1270m  7/15 [nvidia-cuda-nvrtc-cu12]
#     Uninstalling nvidia-cuda-cupti-cu12-12.4.127:━━━━━━━━━━━━━  7/15 [nvidia-cuda-nvrtc-cu12]
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.4.127  7/15 [nvidia-cuda-nvrtc-cu12]
#   Attempting uninstall: nvidia-cublas-cu12m━━━━━━━━━━━━━━━━━━  8/15 [nvidia-cuda-cupti-cu12]
#     Found existing installation: nvidia-cublas-cu12 12.4.5.8━━  8/15 [nvidia-cuda-cupti-cu12]
#     Uninstalling nvidia-cublas-cu12-12.4.5.8:━━━━━━━━━━━━━━━━━  8/15 [nvidia-cuda-cupti-cu12]
#       Successfully uninstalled nvidia-cublas-cu12-12.4.5.8━━━━  8/15 [nvidia-cuda-cupti-cu12]
#   Attempting uninstall: nvidia-cusparse-cu120m━━━━━━━━━━━━━━━  9/15 [nvidia-cublas-cu12]
#     Found existing installation: nvidia-cusparse-cu12 12.3.1.1700m  9/15 [nvidia-cublas-cu12]
#     Uninstalling nvidia-cusparse-cu12-12.3.1.170:━━━━━━━━━━━━━  9/15 [nvidia-cublas-cu12]
#       Successfully uninstalled nvidia-cusparse-cu12-12.3.1.170  9/15 [nvidia-cublas-cu12]
#   Attempting uninstall: nvidia-cufft-cu121m╸━━━━━━━━━━━━━ 10/15 [nvidia-cusparse-cu12]
#     Found existing installation: nvidia-cufft-cu12 11.2.1.3━━━ 10/15 [nvidia-cusparse-cu12]
#     Uninstalling nvidia-cufft-cu12-11.2.1.3:━━━━━━━━━━━━━ 10/15 [nvidia-cusparse-cu12]
#       Successfully uninstalled nvidia-cufft-cu12-11.2.1.3━━━━━ 10/15 [nvidia-cusparse-cu12]
#   Attempting uninstall: nvidia-cudnn-cu12╺━━━━━━━━━━ 11/15 [nvidia-cufft-cu12]
#     Found existing installation: nvidia-cudnn-cu12 9.1.0.70━━━ 11/15 [nvidia-cufft-cu12]
#     Uninstalling nvidia-cudnn-cu12-9.1.0.70:━━━━━━━━━━ 11/15 [nvidia-cufft-cu12]
#       Successfully uninstalled nvidia-cudnn-cu12-9.1.0.70━━━━━ 11/15 [nvidia-cufft-cu12]
#   Attempting uninstall: nvidia-cusolver-cu12╺━━━━━━━ 12/15 [nvidia-cudnn-cu12]
#     Found existing installation: nvidia-cusolver-cu12 11.6.1.9 12/15 [nvidia-cudnn-cu12]
#     Uninstalling nvidia-cusolver-cu12-11.6.1.9:━━━━━━━ 12/15 [nvidia-cudnn-cu12]
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.1.9━━ 12/15 [nvidia-cudnn-cu12]
#   Attempting uninstall: torch━━━━━━━━━━━━━╸━━━━━ 13/15 [nvidia-cusolver-cu12]
#     Found existing installation: torch 2.5.191m╸━━━━━ 13/15 [nvidia-cusolver-cu12]
#     Uninstalling torch-2.5.1:━━━━━━━━━━━━━━━━╺━━ 14/15 [torch]olver-cu12]
#       Successfully uninstalled torch-2.5.1╺━━ 14/15 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/15 [torch]m14/15 [torch]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.5.1 requires torch==2.5.1, but you have torch 2.8.0 which is incompatible.
# torchvision 0.20.1 requires torch==2.5.1, but you have torch 2.8.0 which is incompatible.
# vllm 0.7.2 requires torch==2.5.1, but you have torch 2.8.0 which is incompatible.
# xformers 0.0.28.post3 requires torch==2.5.1, but you have torch 2.8.0 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-nccl-cu12-2.27.3 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvtx-cu12-12.8.90 sympy-1.14.0 torch-2.8.0 triton-3.4.0
# /home/mahdi/miniconda3/envs/myenv/lib/python3.10/site-packages/sae_lens/saes/sae.py:249: UserWarning:
# This SAE has non-empty model_from_pretrained_kwargs.
# For optimal performance, load the model like so:
# model = HookedSAETransformer.from_pretrained_no_processing(..., **cfg.model_from_pretrained_kwargs)
#   warnings.warn(
# /tmp/ipykernel_379415/3012040378.py:5: DeprecationWarning: Unpacking SAE objects is deprecated. SAE.from_pretrained() now returns only the SAE object. Use SAE.from_pretrained_with_cfg_and_sparsity() to get the config dict and sparsity as well.
#   sae, cfg_dict, sparsity = SAE.from_pretrained(

# %% [markdown]
# Full SAELens documentation, tutorials, etc. can be found at https://github.com/jbloomAus/SAELens
